# %% [markdown]
# ## Task 6: Payroll ATS
# 1. Pay slips generate monthly one time
# 2. Cash flow report
# 3. Balance sheet report
# 4. Stack holder distribute (profit) report

# %%
# importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as num

# %%
# loading the data
payslp = pd.read_excel('Kalyani_Balance_Sheet_November_2022.xlsx')
df = payslp.iloc[:, 0:6]
df.head()
# Out:
#               Name Branch Team member    Department  Fees  Chennai  Aurangabad
# 0     Thirumurugan            Kalyani  Data Science   499      100         399
# 1     Harsh Dodiya            Kalyani  Data Science   499      100         399
# 2     Kunal pahuja            Kalyani  Data Science   499      200         299
# 3       Arya Singh            Kalyani  Data Science   499      100         399
# 4  Prashansa Shree            Kalyani  Data Science   499      100         399

# %% [markdown]
# ## 1. payslips generator

# %%
name_block = "Name of intern"
Department = 'Department'
foa = 'Fee of Aurangabad'
foc = 'Fee of Chennai'

# %%
def name(n, d, a, c):
    print('*' * 58)
    print('\t\t\tYOOSHOP\t\t')
    print('\t\tDATA SCIENCE INTERNSHIP PAYSHIP')
    print('=' * 58)
    print('Branch Team Leader\t\t\t   kalyani Ghale')
    print('=' * 58)
    print(f"{name_block.upper()}\t\t\t\t{n}")
    print(f"{Department.upper()}\t\t\t\t{d}")
    print(f"{foa.upper()}\t\t\t\t{a}")
    print(f"{foc.upper()}\t\t\t\t\t{c}")
    print('=' * 58)
    print(f'SUBTOTAL\t\t\t\t\t{a + c}')
    print('\n')

# %%
for i in df.values:
    name(i[0], i[2], i[5], i[4])
# Out:
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Thirumurugan
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Harsh Dodiya
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Kunal pahuja
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Arya Singh
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Prashansa Shree
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Kaushal Sambrani
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Nisha Devi
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Aryan
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Abhishek
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Heramb
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Dhruba Jyoti Seal
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Ritesh Kumar Tripathi
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Khemchandra Mohankar
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Shreyash Sevakram Mane
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Manav Taneja
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Atharva Shashank Madane
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				ARYAN KAUSHIK
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Ruthwick Masidkar
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Ankita Chowdhury
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Santosh kumar pal
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Prachi Bharadwaj
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Ankit Kumar Patel
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Amruta Birappa Khilare-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				G Vasumathi-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Kritik sahu-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Pundlik Sontakke-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Badrinath Khawal-K
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Simran-K
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				N Zeeshan Mouzam-K
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Gungun Nilamwar-K
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Jayaprakash Gedela-K
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Shreya Mukkawar-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Diksha Sharma-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Priyanka S Prabhu-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				300
# FEE OF CHENNAI					199
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Sangram Singh-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				300
# FEE OF CHENNAI					199
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Kamal Soni-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Md Hamza Khan-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Sudhanshu-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				B Suresh Rao-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Amruta Yelwande-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Akash Bangar-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Srijani Chakrabarti-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Mohd Aaqib Sohail-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Tinkal-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Nireeksha R Shetty-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Adhithya Mathew-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Suzana Sharol-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				VINU VAISHAK V-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				400
# FEE OF CHENNAI					99
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Komal
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				400
# FEE OF CHENNAI					99
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				DEDEEPYA
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Preeti
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				MURALI
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Prashanth
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Mohammad Imran-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				300
# FEE OF CHENNAI					199
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Rishabh Bhandari-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Anjanesh Vaidya-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Uday Singh Kushwah-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Muniza kamal-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Md Samroj alam-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				MANJU MOHAN-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Purna Geria-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Riya-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Hemant singh-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Sharsh Parasar-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Avanish Singh-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				DARSHNA PARMAR-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Haritha C M-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Gurukiran Yaraddi-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				KOMAL NAMA-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Somya Agrawal-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Shipra Bhardwaj-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				ARUNESHWAR R-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Sachin Negi-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Satyam Sharma-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Abhishek Wagh-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Shimpy Bansal-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Komal Bhauso Bhintade-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Kiran Patil-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Younus Chilakala-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				300
# FEE OF CHENNAI					199
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Pavitra Chettri-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				300
# FEE OF CHENNAI					199
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Tanuja Suresh Bhosale-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				PANCHAL NIHANSHU-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				SWAPNILA CHAKRABARTY-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				PANCHAL NIHANSHU-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				NITHEESH BHARADWAJ-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Manish Yadav-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				VIPIN CHANDRA NIRALA-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Avantika Kureel -K
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Ashvin Sharma-K
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Infant Alan S-K
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Bhagyashree Ajit More-K
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Prince Kumar-K
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Madhu kumar-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Ishaan Kotwal-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Mayur Amar Adate-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				300
# FEE OF CHENNAI					199
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Shweta Varshney-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Hetkumar Siddhapura-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Khushi Gupta-K
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Komal Sharma-K
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Roopal Vashishth-K
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Ashish Sahu-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Divya Bhendawadekar-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				299
# FEE OF CHENNAI					200
# ==========================================================
# SUBTOTAL					499
#
#
# **********************************************************
# 			YOOSHOP
# 		DATA SCIENCE INTERNSHIP PAYSHIP
# ==========================================================
# Branch Team Leader			   kalyani Ghale
# ==========================================================
# NAME OF INTERN				Ben Jose Joseph-k
# DEPARTMENT				Data Science
# FEE OF AURANGABAD				399
# FEE OF CHENNAI					100
# ==========================================================
# SUBTOTAL					499

# %% [markdown]
# ## 2. cash flow report

# %%
Aurangabad = df['Aurangabad'].sum()
chennai = df['Chennai'].sum()
print('Total Cash Flow in Different cities:-')
a = int(input('Enter a number press 1 for chennai and 2 for Aurangabad :'))
if a == 1:
    print(f'\nTotal Cash Flow in Chennai: {chennai}')
elif a == 2:
    print(f'Total Cash Flow in Aurangabad: {Aurangabad}')
else:
    print('Invalid Selection')
print()
# Out:
# Total Cash Flow in Different cities:-
# Enter a number press 1 for chennai and 2 for Aurangabad :2
# Total Cash Flow in Aurangabad: 36305

# %% [markdown]
# ## 3. balance sheet report

# %%
Aurangabad = df['Aurangabad'].sum()
chennai = df['Chennai'].sum()
print('Total Balance Sheet in Different cities:-')
a = int(input('Enter a number press 1 for chennai and 2 for Aurangabad :'))
if a == 1:
    print(f'\nTotal Balance Sheet in Chennai: {chennai}')
elif a == 2:
    print(f'Total Balance Sheet in Aurangabad: {Aurangabad}')
else:
    print('Invalid Selection')
# Out:
# Total Balance Sheet in Different cities:-
# Enter a number press 1 for chennai and 2 for Aurangabad :2
# Total Balance Sheet in Aurangabad: 36305

# %% [markdown]
# ## 4. stack holder distribute (profit) report

# %%
labels = 'Aurangabad', 'chennai'
sizes = [Aurangabad, chennai]
explode = (0, 0.1)

# %%
fig1, ax1 = plt.subplots()
colors = ['#F66F8D', '#FFB643']
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90, colors=colors)
plt.title('Stack holder profit ratio in different cities', fontsize=14)
ax1.axis('equal')
plt.show();
